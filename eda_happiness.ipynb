# %% [markdown]
# # **World Happiness Report 2005-2022**

# %% [markdown]
# About dataset -
#
# * Country name : The name of the country.
# * Year : The year of the report, i.e from 2005 to 2022.
# * Life Ladder : Respondents are asked to think of a ladder, with the best possible life for them being a 10, and the worst possible life being a 0 and then to rate there own current life as per it.
# * Log GDP per capita : The gross domestic product per capita in purchasing power parity (PPP) adjusted dollars.
# * Social support : The perceived social support (ability to count on others) in the country. Say, freedom to make life choices as the perceived freedom to make life choices in the country.
# * Healthy life expectancy at birth : Can be interpreted as the number of years the average citizen in a country lives happily at a certain time. Life- expectancy in years is multiplied by average happiness.
# * Freedom to make life choices : Freedom to make choices in one's life.
# * Generosity : The perceived generosity of people in the country.
# * Perceptions of corruption : The perceived level of corruption in the government and business sectors of the country.
# * Positive affect : Measure of positive emotion.
# * Negative affect : Measure of negative emotion.
# * Confidence in national government : Confidence in national government is correlated to happiness of citizen.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('/content/World Happiness Report.csv')

# %% [markdown]
# Basic Exploration

# %%
data.head()
# Out:
#   Country Name Regional Indicator  Year  Life Ladder  Log GDP Per Capita  \
# 0  Afghanistan         South Asia  2008     3.723590            7.350416
# 1  Afghanistan         South Asia  2009     4.401778            7.508646
# 2  Afghanistan         South Asia  2010     4.758381            7.613900
# 3  Afghanistan         South Asia  2011     3.831719            7.581259
# 4  Afghanistan         South Asia  2012     3.782938            7.660506
#
#    Social Support  Healthy Life Expectancy At Birth  \
# 0        0.450662                         50.500000
# 1        0.552308                         50.799999
# 2        0.539075                         51.099998
# 3        0.521104                         51.400002
# 4        0.520637                         51.700001
#
#    Freedom To Make Life Choices  Generosity  Perceptions Of Corruption  \
# 0                      0.718114    0.167652                   0.881686
# ...

# %%
data.shape
# Out:
# (2199, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country Name                       2199 non-null   object
#  1   Regional Indicator                 2087 non-null   object
#  2   Year                               2199 non-null   int64
#  3   Life Ladder                        2199 non-null   float64
#  4   Log GDP Per Capita                 2179 non-null   float64
#  5   Social Support                     2186 non-null   float64
#  6   Healthy Life Expectancy At Birth   2145 non-null   float64
#  7   Freedom To Make Life Choices       2166 non-null   float64
#  8   Generosity                         2126 non-null   float64
#  9   Perceptions Of Corruption          2083 non-null   float64
#  10  Positive Affect                    2175 non-null   float64
# ...

# %%
data.columns
# Out:
# Index(['Country Name', 'Regional Indicator', 'Year', 'Life Ladder',
#        'Log GDP Per Capita', 'Social Support',
#        'Healthy Life Expectancy At Birth', 'Freedom To Make Life Choices',
#        'Generosity', 'Perceptions Of Corruption', 'Positive Affect',
#        'Negative Affect', 'Confidence In National Government'],
#       dtype='object')

# %%
data=data.rename(columns={'Country Name':'Country_Name','Regional Indicator':'Regional_Indicator','Life Ladder':'Life_Ladder','Log GDP Per Capita':'Log_GDP_Per_Capita','Social Support':'Social_Support','Healthy Life Expectancy At Birth':'Healthy_Life_Expectancy_At_Birth','Freedom To Make Life Choices':'Freedom_To_Make_Life_Choices','Perceptions Of Corruption':'Perceptions_Of_Corruption','Positive Affect':'Positive_Affect','Negative Affect':'Negative_Affect','Confidence In National Government':'Confidence_In_National_Government'})

# %%
data['Year'].unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2021, 2022, 2007, 2020, 2006, 2005])

# %%
data.describe()
# Out:
#               Year  Life_Ladder  Log_GDP_Per_Capita  Social_Support  \
# count  2199.000000  2199.000000         2179.000000     2186.000000
# mean   2014.161437     5.479226            9.389766        0.810679
# std       4.718736     1.125529            1.153387        0.120952
# min    2005.000000     1.281271            5.526723        0.228217
# 25%    2010.000000     4.646750            8.499764        0.746609
# 50%    2014.000000     5.432437            9.498955        0.835535
# 75%    2018.000000     6.309460           10.373216        0.904792
# max    2022.000000     8.018934           11.663788        0.987343
#
#        Healthy_Life_Expectancy_At_Birth  Freedom_To_Make_Life_Choices  \
# count                       2145.000000                   2166.000000
# mean                          63.294583                      0.747858
# std                            6.901104                      0.140150
# min                            6.720000                      0.257534
# ...

# %% [markdown]
# Checking null values

# %%
data.isnull().sum()
# Out:
# Country_Name                           0
# Regional_Indicator                   112
# Year                                   0
# Life_Ladder                            0
# Log_GDP_Per_Capita                    20
# Social_Support                        13
# Healthy_Life_Expectancy_At_Birth      54
# Freedom_To_Make_Life_Choices          33
# Generosity                            73
# Perceptions_Of_Corruption            116
# Positive_Affect                       24
# Negative_Affect                       16
# Confidence_In_National_Government    361
# dtype: int64

# %%
data.duplicated().value_counts()
# Out:
# False    2199
# dtype: int64

# %%
print(data['Country_Name'].nunique())
# Out:
# 165

# %% [markdown]
# Handling missing values

# %%
data['Log_GDP_Per_Capita'].value_counts(ascending=False)
# Out:
# 7.350416     1
# 9.511735     1
# 8.534989     1
# 8.532351     1
# 8.489840     1
#             ..
# 10.535282    1
# 10.453635    1
# 8.615271     1
# 8.600658     1
# 7.670123     1
# Name: Log_GDP_Per_Capita, Length: 2179, dtype: int64

# %%
data['Log_GDP_Per_Capita'].fillna(0,inplace=True)

# %%
data['Social_Support'].fillna(0,inplace=True)

# %%
data['Healthy_Life_Expectancy_At_Birth'].fillna(0,inplace=True)

# %%
data['Freedom_To_Make_Life_Choices'].fillna(0,inplace=True)

# %%
data['Generosity'].fillna(0,inplace=True)

# %%
data['Perceptions_Of_Corruption'].fillna(0,inplace=True)

# %%
data['Positive_Affect'].fillna(0,inplace=True)

# %%
data['Negative_Affect'].fillna(0,inplace=True)

# %%
data['Confidence_In_National_Government'].fillna(0,inplace=True)

# %%
data['Regional_Indicator'].unique()
# Out:
# array(['South Asia', 'Central and Eastern Europe',
#        'Middle East and North Africa', nan, 'Latin America and Caribbean',
#        'Commonwealth of Independent States', 'North America and ANZ',
#        'Western Europe', 'Sub-Saharan Africa', 'Southeast Asia',
#        'East Asia'], dtype=object)

# %%
data['Regional_Indicator'].value_counts()
# Out:
# Sub-Saharan Africa                    443
# Latin America and Caribbean           321
# Western Europe                        303
# Central and Eastern Europe            241
# Middle East and North Africa          204
# Commonwealth of Independent States    188
# Southeast Asia                        132
# South Asia                             97
# East Asia                              92
# North America and ANZ                  66
# Name: Regional_Indicator, dtype: int64

# %%
data['Regional_Indicator'].fillna('NA',inplace=True)

# %%
data.isnull().sum()
# Out:
# Country_Name                         0
# Regional_Indicator                   0
# Year                                 0
# Life_Ladder                          0
# Log_GDP_Per_Capita                   0
# Social_Support                       0
# Healthy_Life_Expectancy_At_Birth     0
# Freedom_To_Make_Life_Choices         0
# Generosity                           0
# Perceptions_Of_Corruption            0
# Positive_Affect                      0
# Negative_Affect                      0
# Confidence_In_National_Government    0
# dtype: int64

# %% [markdown]
# Analysis

# %%
fig = plt.subplots(figsize=(10, 5))
sns.heatmap(data.corr(), annot = True)
plt.title("Relationship Between Features ")
plt.show()
# Out:
# <ipython-input-81-1bd2b28e7c86>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot = True)

# %%
sns.distplot(data['Life_Ladder'],color='Black',kde=False,bins=10)
# Out:
# <ipython-input-69-2b48bf0a6473>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Life_Ladder'],color='Black',kde=False,bins=10)
# <Axes: xlabel='Life_Ladder'>

# %%
sns.jointplot(x=data['Confidence_In_National_Government'],y=data['Perceptions_Of_Corruption'],data=data,color='green')

# %%
plt.boxplot(data['Healthy_Life_Expectancy_At_Birth'],vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fd601e48040>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fd601e4ace0>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x7fd60447bfa0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd601e4b310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd601e4b340>],
#  'means': []}

# %%
sns.jointplot(x=data['Generosity'],y=data['Social_Support'],kind='scatter',data=data,color='chocolate')

# %%
sns.jointplot(x=data['Year'],y=data['Freedom_To_Make_Life_Choices'],data=data,kind='reg',color='darkslateblue')

# %%
x=data['Life_Ladder']
y=data['Log_GDP_Per_Capita']
plt.scatter(x,y,color='cadetblue')

# %%
sns.distplot(data['Negative_Affect'],kde=True,color='steelblue')
# Out:
# <ipython-input-75-f7ad791fdcc6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Negative_Affect'],kde=True,color='steelblue')
# <Axes: xlabel='Negative_Affect', ylabel='Density'>

# %%
plt.boxplot(data['Freedom_To_Make_Life_Choices'],vert=True,patch_artist='crimson')
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fd5fdcce3e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fd5fdcce920>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x7fd5fdcce050>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd5fdccee90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd5fde5b6d0>],
#  'means': []}

# %%
sns.pairplot(data)

# %% [markdown]
# Summary
#
#
#
# *   The average life expectancy at birth is 63% for 165 countries.
# *   On a scale of 1 to 10, the maximum rate given for Life Ladder is 8 among 2199 unique count.
#
# * There is a very positive, strong relationship between Life Ladder Log GDP per capita as well.
#
# * The World Happiness Report for the years 2005 - 2022 has been conducted among 165 countries where 1838 unique confidence in national government count is recorded.
#
# * The average life ladder is recorded as 5.47 on of a scale 1 to 10.
#
# * There seems to be a positive relationship between the columns 'Confidence in national government' and 'Perceptions of corruption'.
#
# * There is strong relationship between Generosity and Social support.
